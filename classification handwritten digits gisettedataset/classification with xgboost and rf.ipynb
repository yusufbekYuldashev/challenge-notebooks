# %%
# !pip install boruta
# !pip install xgboost
# Out:
# Requirement already satisfied: boruta in c:\users\ine_std\anaconda3\lib\site-packages (0.3)
# Requirement already satisfied: scikit-learn>=0.17.1 in c:\users\ine_std\anaconda3\lib\site-packages (from boruta) (1.1.1)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\ine_std\anaconda3\lib\site-packages (from boruta) (1.22.3)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\ine_std\anaconda3\lib\site-packages (from boruta) (1.9.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ine_std\anaconda3\lib\site-packages (from scikit-learn>=0.17.1->boruta) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\ine_std\anaconda3\lib\site-packages (from scikit-learn>=0.17.1->boruta) (1.1.0)
# Collecting xgboost
#   Downloading xgboost-1.6.2-py3-none-win_amd64.whl (125.4 MB)
#      -------------------------------------- 125.4/125.4 MB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\ine_std\anaconda3\lib\site-packages (from xgboost) (1.22.3)
# Requirement already satisfied: scipy in c:\users\ine_std\anaconda3\lib\site-packages (from xgboost) (1.9.0)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.6.2

# %%
import os
import zipfile 
import random
import pickle
import matplotlib.pyplot as plt
import urllib.request
import numpy as np
import seaborn as sns
# %matplotlib inline
from sklearn.decomposition import PCA

# %%
# data_file_name = './archive.zip'
# dir = './dataset'
# zip_ref = zipfile.ZipFile(data_file_name, 'r')
# zip_ref.extractall(dir)
# zip_ref.close()

# %%
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo)
    return dict

gisette_data = unpickle("./dataset/gisette.pickle")

# %%
train_data = gisette_data['training']['data']
train_labels = gisette_data['training']['labels'] # label 1 for digit 4,   label -1 for digit 9
print(type(train_labels), train_labels)

validation_data = gisette_data['validation']['data']
validation_labels = gisette_data['validation']['labels']

test_data = gisette_data['testing']['data']

train_labels = np.array([int(x) if x > 0 else 0 for x in train_labels])
print(type(train_labels), train_labels)
validation_labels = np.array([int(x)  if x > 0 else 0 for x in validation_labels])
# Out:
# <class 'numpy.ndarray'> [ 1. -1.  1. ... -1. -1. -1.]
# <class 'numpy.ndarray'> [1 0 1 ... 0 0 0]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(train_data)
X_train = scaler.transform(train_data)
X_valid = scaler.transform(validation_data)
X_test = scaler.transform(test_data)

# %%
import xgboost as xgb

model = xgb.XGBClassifier()
model.fit(X_train, train_labels)
model.
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
# from boruta import BorutaPy
# feature_selector = BorutaPy(model, n_estimators=200, verbose=2, random_state=42, max_iter=20)
# feature_selector.fit(X_train, train_labels)
# print(feature_selector.suport_)
# print(feature_selector.ranking_)
# X_train_filtered = feature_selector.transform(X_train)
# X__filtered = feature_selector.transform(X_valid)

pca = PCA(n_components=2500)
X_train = pca.fit_transform(X_train)

# %%
print(X_train.shape)
# Out:
# (6000, 2500)
